# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from word2number import w2n
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
dataset = pd.read_csv(r'D:\PYTHON Practice Projecs\Train_3.csv')

# %%
dataset.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
dataset.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
dataset.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
dataset.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
## display all colmns of the df

pd.options.display.max_columns = 100

# %% [markdown]
# #### For starters we do the following
# 1. Missing values
# 2. All numeric variables & their distrbution
# 3. Categorcal variables &  possible values that a feature can assume
# 4. Outliers
# 5. Relationship btw independent & dependent variables

# %%
dataset.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %% [markdown]
# ## Create null features

# %%
df1.groupby(['YrSold'])['SalePrice'].median().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-92344d0e126d> in <module>
# ----> 1 df1.groupby(['YrSold'])['SalePrice'].median().plot()
#
# NameError: name 'df1' is not defined

# %%
## First : create a list of features name containing missing values using list comprehension

features_null = [features for features in dataset.columns if dataset[features].isnull().sum()>1]   ## atleast 1 null in any feature
df = dataset.copy()
## Next : find % of null values in each feature 

for features in features_null:
    print(features,np.round(df[features].isnull().mean(),4), '% missing values')
# Out:
# LotFrontage 0.1774 % missing values
# Alley 0.9377 % missing values
# MasVnrType 0.0055 % missing values
# MasVnrArea 0.0055 % missing values
# BsmtQual 0.0253 % missing values
# BsmtCond 0.0253 % missing values
# BsmtExposure 0.026 % missing values
# BsmtFinType1 0.0253 % missing values
# BsmtFinType2 0.026 % missing values
# FireplaceQu 0.4726 % missing values
# GarageType 0.0555 % missing values
# GarageYrBlt 0.0555 % missing values
# GarageFinish 0.0555 % missing values
# GarageQual 0.0555 % missing values
# GarageCond 0.0555 % missing values
# PoolQC 0.9952 % missing values
# Fence 0.8075 % missing values
# MiscFeature 0.963 % missing values

# %%
features_null
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %% [markdown]
# ## FIND relationship btw Missing values & Sales Price

# %%
## Missing values relationships with sales price
## Make Null as 1 else 0 
for features in features_null:
    df = dataset.copy()
    
    df[features] = np.where(df[features].isnull(),1,0)        ## To create count Plot
    
    
    ## Mean sales price where the information is missing or present
    df.groupby(features)['SalePrice'].median().plot.bar()
    plt.show()

# %% [markdown]
# ## Here the relation btw missing values and dependable variable is visible, so we have to replace it with more meaningfull values using feature engineering

# %%
##  Create year features to avoid appearance in discrete features

year_features = [ features for features in numeric_features if 'Yr' in features or 'Year' in features]
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
## Finding all numeric features using list comprehension
numeric_features = [features for features in df.columns if df[features].dtypes != 'O']

## Discrete/continuos Features
discrete_features = [features for features in numeric_features if len(df[features].unique())<25 and features not in year_features]
for features in discrete_features:
    df = dataset.copy()
    df.groupby(features)['SalePrice'].median().plot.bar()
    plt.ylabel('SalePrce')
    plt.title(features)
    plt.show()

## Continuous numeric Features( using list comprehension)
continuous_features = [features for features in numeric_features if features not in discrete_features+year_features+['Id']]

for features in continuous_features:
    df= dataset.copy()
    df[features] = np.log(df[features])
    df['SalePrice'] = np.log(df['SalePrice'])
    plt.scatter(df[features],df['SalePrice'])
    plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
categ_features = [features for features in df.columns if df[features].dtypes() == 'O']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-233d0c550558> in <module>
# ----> 1 categ_features = [features for features in df.columns if df[features].dtypes() == 'O']
#
# <ipython-input-22-233d0c550558> in <listcomp>(.0)
# ----> 1 categ_features = [features for features in df.columns if df[features].dtypes() == 'O']
#
# TypeError: 'numpy.dtype[int64]' object is not callable

# %% [markdown]
# ### IF data is skewed , we would be using log transformation

# %%
continuous_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for features in continuous_features:
    df = dataset.copy()
    if 0 in df[features].unique():
        pass
else:
    df[features] = np.log(df[features])
    df['SalePrice'] = np.log(df['SalePrice'])
    plt.scatter(df[features], df['SalePrice'])
    
    plt.show()

# %% [markdown]
# ## Outliers For numeric variables

# %%
for features in continuous_features:
    df = dataset.copy()
    if 0 in df[features].unique():
        pass 
    else:
        df['SalePrice'] = np.log(df['SalePrice'])
        df[features] = np.log(df[features])
        df.boxplot(column=features)
        plt.show()

# %%
for features in discrete_features:
    df = dataset.copy()
    if 0 in df[features].unique():
        pass
    else:
        df[features] = np.log(df[features])
        df.boxplot(column= features)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'float' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-026fe9688f3e> in <module>
#       4         pass
#       5     else:
# ----> 6         df[features] = np.log(df[features])
#       7         df.boxplot(column= features)
#       8         plt.show()
#
# D:\ANACONDA\lib\site-packages\pandas\core\generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    1934         self, ufunc: Callable, method: str, *inputs: Any, **kwargs: Any
#    1935     ):
# -> 1936         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    1937
#    1938     # ideally we would define this to avoid the getattr checks, but
#
# ...

# %% [markdown]
# ## Categorical variables

# %%
categorical_features = [features for features in df.columns if df[features].dtypes() == 'O']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4796f029b522> in <module>
# ----> 1 categorical_features = [features for features in df.columns if df[features].dtypes() == 'O']
#
# <ipython-input-27-4796f029b522> in <listcomp>(.0)
# ----> 1 categorical_features = [features for features in df.columns if df[features].dtypes() == 'O']
#
# TypeError: 'numpy.dtype[int64]' object is not callable

# %% [markdown]
# ## Handeling missing Data

# %% [markdown]
# 1. #### Continuous data
# 2. #### Categorical data

# %%
df2 = pd.read_csv(r'D:\PYTHON Practice Projecs\train.csv')

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2['Cabin_null'] = np.where(df2['Cabin'].isnull(),1,0)

# %% [markdown]
# ## Techniques of handeling missing values
# 1. Mean / median , mode Replacement/ Imputation
# 2. Random Sample imputation
# 3. Capturing Nan values with a unique feature
# 4. End of distributon imputation
# 5. Arbitraty imputaion
# 6. Frequent feature imptation

# %% [markdown]
# #### Mean / Median Replacement has assumption MCAR (Missing Completely at random)
# We Solve this by replacing with most frequent value
#
# Disadvantages >> Distorts variance

# %%
df3 = pd.read_csv(r'D:\PYTHON Practice Projecs\train.csv', usecols=['Age','Fare','Survived'])

# %%
# seeing % of missing values
df3.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
df3['Age'].median()
# Out:
# 28.0

# %%
df3['Age'] = df3['Age'].fillna(value= df3['Age'].median())

# %% [markdown]
# ## Random Sample imputation
# #### Aim : RSI consist of taking random observation from the dataset , & we use these observation to replace Nan values
# When it should be used : when data is MCAR
#
#
# #### advantages>> variance of data is less
# #### disadvantage >> In every situation it may not work

# %%
df4 = pd.read_csv(r'D:\PYTHON Practice Projecs\train.csv', usecols=['Age','Fare','Survived'])

# %%
df4.dtypes
# Out:
# Survived      int64
# Age         float64
# Fare        float64
# dtype: object

# %%
#% of null values
df4.isnull().mean()
# Out:
# Survived      0.000000
# Age           0.198653
# Fare          0.000000
# Age_median    0.000000
# Age_random    0.000000
# dtype: float64

# %%
#### Replacing Nan values with some sampled values
df4['Age'].dropna().sample(df4['Age'].isnull().sum(),random_state= 0)
# Out:
# 423    28.00
# 177    50.00
# 305     0.92
# 292    36.00
# 889    26.00
#        ...
# 539    22.00
# 267    25.00
# 352    15.00
# 99     34.00
# 689    15.00
# Name: Age, Length: 177, dtype: float64

# %%
def impute_nan(df,features,median):
    df[features+'_median'] = df[features].fillna(median)
    df[features+'_random'] = df[features]
    # Creating random sample
    random_sample = df[features].dropna().sample(df[features].isnull().sum(),random_state = 0)
    # Matching index
    random_sample.index = df[df[features].isnull()].index
    df.loc[df[features].isnull(),features+'_random']= random_sample

    
median = df4['Age'].median()    
impute_nan(df4,'Age',median)

## Plotting median & random imputation
fig = plt.figure()
ax = fig.add_subplot(111)
df4['Age'].plot(kind='kde', ax=ax)
df4.Age_median.plot(kind='kde', ax=ax, color='red')
df4.Age_random.plot(kind='kde', ax=ax, color='green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %% [markdown]
# ## Capturing Nan values with a unique feature
# #### Works when data is not MCAR
# (missing values have some relationship)

# %%
df3 = pd.read_csv(r'D:\PYTHON Practice Projecs\train.csv', usecols=['Age','Fare','Survived'])

# %%
df3.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
## creating a new feature 
df3['Age_Nan'] = np.where(df3['Age'].isnull(),1,0)

# %% [markdown]
# ## End of distributon imputation

# %%
df3 = pd.read_csv(r'D:\PYTHON Practice Projecs\train.csv', usecols=['Age','Fare','Survived'])

# %%
# Third standard deviation
extreme = df3['Age'].mean()+3*df3['Age'].std()

# %%
## There are outliers
sns.boxplot('Age',data=df3)
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
def endof_dist(df,features,median,extreme):
    df3[features+'_endof_distribution'] = df3[features].fillna(extreme)
    df[features].fillna(median,inplace = True)

# %%
endof_dist(df3,'Age', df3['Age'].median(),extreme)

# %%
df3['Age_endof_distribution'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
## No outliers
sns.boxplot('Age_endof_distribution',data=df3)
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age_endof_distribution'>
